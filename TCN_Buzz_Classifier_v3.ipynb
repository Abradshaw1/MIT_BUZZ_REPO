# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score
import random
from datetime import datetime
import multiprocessing as mp
from pytorch_tcn import TCN
# Import the module
from audio_processing import get_file_paths_and_labels, load_and_resample_audio, extract_mfcc, MFCCDataset

# Set multiprocessing start method to 'spawn'
mp.set_start_method('spawn', force=True)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# Function to save and load the model
def save_model(model, path):
    torch.save(model.state_dict(), path)

def load_model(model, path):
    model.load_state_dict(torch.load(path))
    model.to(device)

base_dir = r'/home/gridsan/abradshaw/MIT Buzz'
model_save_path = os.path.join(base_dir, 'saved_tcn_model.pth')

# Get file paths and labels
file_paths, labels = get_file_paths_and_labels(base_dir)

# Collect first five files for each label category
negative_files = [(path, label) for path, label in zip(file_paths, labels) if label == 0][:5]
positive_files = [(path, label) for path, label in zip(file_paths, labels) if label == 1][:5]

print("First five files in negative dataset (label 0):")
for file_path, label in negative_files:
    print(f"File: {file_path}, Label: {label}")

print("\nFirst five files in positive dataset (label 1):")
for file_path, label in positive_files:
    print(f"File: {file_path}, Label: {label}")

print(f"Found {len(file_paths)} audio files.")

# Iterate through all file paths and process each file
for file_path in file_paths:
    y, sr = load_and_resample_audio(file_path)
    if y is not None:
        mfcc_features = extract_mfcc(y, sr)
        if mfcc_features is not None:
            print(f"Extracted MFCCs for file {file_path}. Shape: {mfcc_features.shape}")
        else:
            print(f"Failed to extract MFCCs for file {file_path}.")
    else:
        print(f"Failed to load audio for file {file_path}.")
# Out:
# /home/gridsan/abradshaw/.conda/envs/python39++/lib/python3.9/site-packages/pytorch_tcn/tcn.py:12: UserWarning:
#         The deprecated weight_norm from torch.nn.utils.weight_norm was imported.
#         Update your PyTorch version to get rid of this warning.
#
#   warnings.warn(
# Using device: cuda
# First five files in negative dataset (label 0):
# File: /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2914_segment_9.mp3, Label: 0
# File: /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_389_segment_11.mp3, Label: 0
# File: /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_676_segment_1.mp3, Label: 0
# File: /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_473_segment_18.mp3, Label: 0
# File: /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2717_segment_11.mp3, Label: 0
#
# First five files in positive dataset (label 1):
# File: /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_892_segment_18.mp3, Label: 1
# File: /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_872_segment_18.mp3, Label: 1
# File: /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_819_segment_1.mp3, Label: 1
# File: /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_2313_segment_4.mp3, Label: 1
# File: /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_2315_segment_18.mp3, Label: 1
# Found 13062 audio files.
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2914_segment_9.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_389_segment_11.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_676_segment_1.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_473_segment_18.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2717_segment_11.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_1702_segment_3.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_2521_segment_0.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_1063_segment_7.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2865_segment_9.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_1676_segment_1.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_112_segment_12.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2583_segment_4.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2653_segment_18.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_2567_segment_10.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_1093_segment_14.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_25_segment_16.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_2519_segment_6.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_31_segment_0.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_3003_segment_13.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2955_segment_4.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2900_segment_17.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_1139_segment_12.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_1842_segment_3.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_687_segment_13.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_1532_segment_16.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_1553_segment_2.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_1659_segment_17.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_1399_segment_10.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_196_segment_3.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_1082_segment_16.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_153_segment_18.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_649_segment_18.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_2250_segment_13.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_389_segment_9.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_1487_segment_14.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2773_segment_11.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_370_segment_7.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_1716_segment_18.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_2146_segment_18.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_3211_segment_15.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_2340_segment_18.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_3266_segment_11.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_252_segment_14.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_1346_segment_15.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2953_segment_6.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_109_segment_10.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2427_segment_8.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_320_segment_2.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_3101_segment_8.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_2527_segment_15.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_3214_segment_16.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2676_segment_10.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_2284_segment_7.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_3217_segment_2.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_2543_segment_14.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_3139_segment_18.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_27_segment_12.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_1821_segment_2.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_1848_segment_13.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_696_segment_12.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_1095_segment_3.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_320_segment_9.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_2153_segment_4.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_258_segment_16.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_3046_segment_10.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_476_segment_15.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_1088_segment_2.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_868_segment_16.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2863_segment_5.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_1220_segment_18.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_258_segment_8.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_110_segment_1.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2524_segment_4.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2860_segment_7.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2907_segment_16.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_1324_segment_2.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2860_segment_6.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_2521_segment_5.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_3113_segment_17.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_696_segment_0.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2259_segment_17.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_2365_segment_0.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_48_segment_13.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_15_segment_13.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_15_segment_10.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_3077_segment_0.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_3101_segment_10.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_2318_segment_2.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2956_segment_9.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2895_segment_16.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_1835_segment_12.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2709_segment_9.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_476_segment_7.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2972_segment_0.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_413_segment_9.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_2257_segment_1.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_506_segment_5.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_1487_segment_9.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_447_segment_12.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_1821_segment_7.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_1204_segment_6.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_153_segment_9.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2435_segment_2.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2986_segment_17.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_625_segment_13.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_868_segment_18.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_1069_segment_10.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2895_segment_0.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_526_segment_18.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_22_segment_12.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_1213_segment_1.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_1595_segment_11.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_1857_segment_14.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_3380_segment_15.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_3101_segment_17.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_47_segment_17.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_31_segment_11.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_110_segment_16.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2691_segment_17.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_1676_segment_15.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_46_segment_8.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_1022_segment_18.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_260_segment_3.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2676_segment_8.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_1506_segment_15.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_875_segment_16.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2704_segment_2.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2927_segment_17.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_394_segment_3.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_2715_segment_10.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_22_segment_17.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_2542_segment_3.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_1654_segment_7.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_1655_segment_8.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_117_segment_18.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_1242_segment_18.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_442_segment_11.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_1264_segment_11.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_1461_segment_5.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_595_segment_16.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_2248_segment_5.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_3077_segment_10.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_260_segment_0.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_327_segment_8.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_476_segment_13.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_3164_segment_12.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2866_segment_15.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_2611_segment_1.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_2337_segment_18.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_3070_segment_2.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_1503_segment_8.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_1576_segment_7.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_3214_segment_11.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_2019_segment_4.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_1513_segment_2.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2902_segment_10.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_46_segment_1.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_122_segment_14.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_327_segment_17.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_3277_segment_0.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2927_segment_9.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_1093_segment_1.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_3105_segment_15.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_482_segment_15.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_1337_segment_0.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_2280_segment_6.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_3185_segment_4.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_108_segment_6.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_1516_segment_2.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_1659_segment_3.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2931_segment_13.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_109_segment_9.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_1220_segment_12.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_1831_segment_15.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_46_segment_17.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_1264_segment_14.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_2401_segment_13.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_644_segment_16.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_1022_segment_13.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_1655_segment_16.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_2674_segment_1.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2866_segment_10.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_1525_segment_9.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2914_segment_15.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_2669_segment_9.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_2523_segment_9.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_892_segment_18.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2435_segment_15.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_1639_segment_18.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_1404_segment_3.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_15_segment_4.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_1827_segment_16.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2698_segment_1.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_684_segment_7.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2730_segment_14.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_1644_segment_8.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_446_segment_7.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_687_segment_0.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_474_segment_14.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_1213_segment_8.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_117_segment_2.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2501_segment_14.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_1346_segment_6.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_1812_segment_16.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_2330_segment_5.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_252_segment_5.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_1526_segment_14.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_33_segment_0.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_3220_segment_2.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_3281_segment_2.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_1513_segment_12.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_2527_segment_14.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_3164_segment_2.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_621_segment_5.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_2257_segment_2.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_3104_segment_16.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2707_segment_11.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2953_segment_8.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_891_segment_8.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2259_segment_6.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2479_segment_8.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_528_segment_14.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_2488_segment_18.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_1702_segment_13.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_1857_segment_16.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_2153_segment_18.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_1576_segment_18.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_1487_segment_5.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_2370_segment_7.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_554_segment_1.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_1532_segment_2.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_875_segment_3.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_1516_segment_1.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2907_segment_9.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_1542_segment_9.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_1593_segment_11.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_3380_segment_0.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_3281_segment_4.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2501_segment_4.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_1654_segment_18.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_342_segment_14.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_1805_segment_8.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_43_segment_16.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_1556_segment_10.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_1516_segment_5.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_3081_segment_17.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_1472_segment_6.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_1290_segment_11.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_482_segment_2.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2673_segment_16.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_2365_segment_10.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_1639_segment_13.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_3071_segment_4.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_447_segment_10.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_2330_segment_7.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_110_segment_12.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_1510_segment_13.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_2250_segment_2.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_1482_segment_6.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_681_segment_16.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2854_segment_10.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_3103_segment_17.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2914_segment_3.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_1327_segment_8.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_3074_segment_12.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_3041_segment_14.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2986_segment_7.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_1506_segment_12.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_1069_segment_11.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_1022_segment_1.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_54_segment_7.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_1853_segment_16.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_2340_segment_8.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_1641_segment_5.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_1450_segment_7.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2709_segment_17.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_892_segment_11.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_888_segment_16.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_1576_segment_13.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_1669_segment_16.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2860_segment_16.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_122_segment_2.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_454_segment_0.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_2488_segment_7.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_1204_segment_14.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_1290_segment_1.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_413_segment_8.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2526_segment_18.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_224_segment_15.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_1344_segment_8.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_39_segment_1.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_3217_segment_12.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_618_segment_3.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_3113_segment_18.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_1068_segment_16.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_48_segment_14.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_70_segment_8.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_1088_segment_13.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2773_segment_10.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_1094_segment_17.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_30_segment_13.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_47_segment_18.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_3101_segment_18.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_442_segment_18.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_468_segment_17.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2920_segment_16.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_3099_segment_8.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_3005_segment_6.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_2542_segment_0.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2906_segment_17.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2259_segment_16.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_476_segment_6.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_592_segment_10.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2865_segment_12.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_59_segment_16.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2621_segment_2.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_543_segment_13.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_20_segment_10.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_1068_segment_1.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_1204_segment_15.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_1556_segment_18.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_22_segment_18.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_1579_segment_3.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_1473_segment_6.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_888_segment_4.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_27_segment_17.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_367_segment_6.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_3369_segment_7.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2939_segment_3.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2013_segment_11.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2678_segment_4.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_1516_segment_17.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_1848_segment_12.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2730_segment_17.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2470_segment_17.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_892_segment_12.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_2406_segment_10.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_1812_segment_10.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2318_segment_16.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_1063_segment_5.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_2674_segment_7.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_1063_segment_11.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_3139_segment_16.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_1344_segment_9.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_891_segment_14.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_644_segment_13.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_108_segment_11.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_2967_segment_14.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_3041_segment_10.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Native_sample_45_segment_0.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_577_segment_18.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/negative_dataset_1sec/Invasive_sample_1576_segment_15.mp3. Shape: (101, 30)
# ...
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_844_segment_12.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_1171_segment_0.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_980_segment_11.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_1881_segment_4.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Native_sample_738_segment_4.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_724_segment_5.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_1955_segment_0.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_1596_segment_2.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Native_sample_391_segment_14.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_1862_segment_14.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Native_sample_1351_segment_3.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_2312_segment_4.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_1030_segment_13.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Native_sample_746_segment_11.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Native_sample_958_segment_5.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Native_sample_2224_segment_13.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Native_sample_3229_segment_9.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_786_segment_5.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_300_segment_6.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_302_segment_3.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_1135_segment_18.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Native_sample_2542_segment_1.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_1161_segment_14.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_486_segment_7.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_799_segment_7.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Native_sample_705_segment_1.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Native_sample_1935_segment_3.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_208_segment_12.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_165_segment_4.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Native_sample_789_segment_2.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Native_sample_78_segment_17.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Native_sample_912_segment_0.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_202_segment_0.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_699_segment_15.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_788_segment_17.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_1171_segment_6.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_1163_segment_11.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Native_sample_894_segment_12.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Native_sample_1010_segment_17.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_1117_segment_5.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_1824_segment_13.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Native_sample_455_segment_2.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Native_sample_2221_segment_16.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_1164_segment_9.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_1581_segment_10.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Native_sample_505_segment_12.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_1960_segment_3.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Native_sample_2454_segment_3.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Native_sample_803_segment_4.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Native_sample_1934_segment_1.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_2397_segment_2.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_1936_segment_5.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Native_sample_2564_segment_9.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Native_sample_1013_segment_12.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Native_sample_1227_segment_5.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Native_sample_2242_segment_2.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Native_sample_1850_segment_11.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_335_segment_5.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_2334_segment_18.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Native_sample_2190_segment_5.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Native_sample_1136_segment_3.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_1581_segment_8.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Native_sample_977_segment_2.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Native_sample_1837_segment_14.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Native_sample_244_segment_6.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_1981_segment_14.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Native_sample_403_segment_5.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_1687_segment_11.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_876_segment_18.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_1837_segment_6.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Native_sample_1929_segment_3.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_891_segment_16.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Native_sample_1880_segment_1.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_2651_segment_11.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_10_segment_15.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_137_segment_10.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Native_sample_790_segment_12.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_609_segment_17.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_1945_segment_18.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Native_sample_1745_segment_3.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Native_sample_2497_segment_6.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Native_sample_812_segment_9.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Native_sample_845_segment_0.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Native_sample_2357_segment_9.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_974_segment_0.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Native_sample_1196_segment_12.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Native_sample_1309_segment_14.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_1808_segment_12.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Native_sample_1381_segment_9.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_1120_segment_11.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Native_sample_2289_segment_18.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_1097_segment_15.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_2467_segment_8.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_1131_segment_16.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_42_segment_1.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_102_segment_5.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Native_sample_2177_segment_4.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Native_sample_2049_segment_11.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_1892_segment_6.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Native_sample_230_segment_16.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Native_sample_913_segment_11.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Native_sample_2220_segment_8.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_1935_segment_0.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_2639_segment_14.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Native_sample_2138_segment_14.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_1883_segment_0.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Native_sample_2255_segment_9.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Native_sample_2252_segment_2.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_785_segment_15.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Native_sample_2290_segment_13(1).mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Native_sample_844_segment_9.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_996_segment_18.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_1566_segment_1.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Native_sample_2246_segment_12.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_1834_segment_12.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_210_segment_0.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Native_sample_3009_segment_7.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Native_sample_2090_segment_5.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_1567_segment_1.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_1962_segment_0.mp3. Shape: (101, 30)
# Extracted MFCCs for file /home/gridsan/abradshaw/MIT Buzz/positive_dataset_1sec/Invasive_sample_1207_segment_0.mp3. Shape: (101, 30)

# %%
print("Creating dataset...")
dataset = MFCCDataset(file_paths, labels)
print("Dataset created")

# Split the data into training, validation, and test sets
train_files, temp_files, train_labels, temp_labels = train_test_split(file_paths, labels, test_size=0.4, random_state=42)
val_files, test_files, val_labels, test_labels = train_test_split(temp_files, temp_labels, test_size=0.5, random_state=42)

train_dataset = MFCCDataset(train_files, train_labels)
val_dataset = MFCCDataset(val_files, val_labels)
test_dataset = MFCCDataset(test_files, test_labels)

batch_size = 32
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
# Out:
# Creating dataset...
# Dataset created

# %%
class TCNModel(nn.Module):
    def __init__(self, num_inputs, num_channels, kernel_size, dropout, causal, use_norm, activation):
        super(TCNModel, self).__init__()
        self.tcn = TCN(
            num_inputs=num_inputs,
            num_channels=num_channels,
            kernel_size=kernel_size,
            dropout=dropout,
            causal=causal,
            use_norm=use_norm,
            activation=activation
        )
        self.bn = nn.BatchNorm1d(num_channels[-1])
        self.fc = nn.Linear(num_channels[-1], 1)
        nn.init.kaiming_normal_(self.fc.weight, nonlinearity='relu')

    def forward(self, x):
        x = self.tcn(x)
        x = self.bn(x)
        x = torch.mean(x, dim=2)
        x = self.fc(x)
        return x

# Instantiate the model
model = TCNModel(
    num_inputs=30,
    num_channels=[16, 32, 64, 128],
    kernel_size=5,
    dropout=0.4,
    causal=False,
    use_norm='weight_norm',
    activation='relu'
).to(device)

criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
def train(model, dataloader, criterion, optimizer, device, num_epochs=20, clip_value=1.0):
    for epoch in range(num_epochs):
        model.train()
        total_loss = 0
        all_preds = []
        all_labels = []
        for mfcc_batch, labels_batch in dataloader:
            if mfcc_batch is None:
                continue
            mfcc_batch, labels_batch = mfcc_batch.to(device), labels_batch.unsqueeze(-1).to(device)
            optimizer.zero_grad()
            outputs = model(mfcc_batch)
            loss = criterion(outputs, labels_batch)
            loss.backward()
            nn.utils.clip_grad_norm_(model.parameters(), clip_value)
            optimizer.step()
            total_loss += loss.item()
            preds = torch.round(torch.sigmoid(outputs)).detach().cpu().numpy()  # Detach before converting to numpy
            all_preds.extend(preds)
            all_labels.extend(labels_batch.cpu().numpy())
        accuracy = accuracy_score(all_labels, all_preds)
        print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {total_loss/len(dataloader):.4f}, Accuracy: {accuracy:.4f}")
save_model(model, 'saved_tcn_model.pth')

# %%
def evaluate(model, dataloader, criterion, device):
    model.eval()
    total_loss = 0
    all_preds = []
    all_labels = []
    with torch.no_grad():
        for mfcc_batch, labels_batch in dataloader:
            if mfcc_batch is None:
                continue
            mfcc_batch, labels_batch = mfcc_batch.to(device), labels_batch.unsqueeze(-1).to(device)
            outputs = model(mfcc_batch)
            loss = criterion(outputs, labels_batch)
            total_loss += loss.item()
            preds = torch.round(torch.sigmoid(outputs)).detach().cpu().numpy()
            all_preds.extend(preds)
            all_labels.extend(labels_batch.cpu().numpy())
    avg_loss = total_loss / len(dataloader)
    accuracy = accuracy_score(all_labels, all_preds)
    f1 = f1_score(all_labels, all_preds)
    precision = precision_score(all_labels, all_preds)
    print(f"Validation - Loss: {avg_loss:.4f}, Accuracy: {accuracy:.4f}, F1 Score: {f1:.4f}, Precision: {precision:.4f}")
    return avg_loss, accuracy, all_preds, all_labels

# %%
def manual_validation(file_paths, labels, preds, base_dir, num_samples=100):
    correct_files = []
    false_positives = []
    false_negatives = []

    output_dir = os.path.join(base_dir, 'manual_validation_results')
    os.makedirs(output_dir, exist_ok=True)
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    output_file_path = os.path.join(output_dir, f'validation_results_{timestamp}.txt')
    
    for i, (label, pred) in enumerate(zip(labels, preds)):
        file_path = file_paths[i]
        if label == pred:
            correct_files.append((file_path, pred, label))
        elif label == 0 and pred == 1:
            false_positives.append((file_path, pred, label))
        elif label == 1 and pred == 0:
            false_negatives.append((file_path, pred, label))
    
    accuracy = accuracy_score(labels, preds)
    f1 = f1_score(labels, preds, zero_division=1)
    precision = precision_score(labels, preds, zero_division=1)
    
    with open(output_file_path, 'w') as f:
        f.write(f"Cross-validation Results:\n")
        f.write(f"Accuracy: {accuracy:.4f}, F1 Score: {f1:.4f}, Precision: {precision:.4f}\n")
        f.write(f"Total Correct: {len(correct_files)}\n")
        f.write(f"Total False Positives: {len(false_positives)}\n")
        f.write(f"Total False Negatives: {len(false_negatives)}\n\n")
        
        sample_correct = random.sample(correct_files, min(len(correct_files), num_samples))
        sample_false_positives = random.sample(false_positives, min(len(false_positives), num_samples))
        sample_false_negatives = random.sample(false_negatives, min(len(false_negatives), num_samples))
        
        f.write("Sampled Correct Predictions:\n")
        for fp, pred, label in sample_correct:
            f.write(f"File: {fp}, Prediction: {pred}, True Label: {label}\n")
        
        f.write("\nSampled False Positives:\n")
        for fp, pred, label in sample_false_positives:
            f.write(f"File: {fp}, Prediction: {pred}, True Label: {label}\n")
        
        f.write("\nSampled False Negatives:\n")
        for fp, pred, label in sample_false_negatives:
            f.write(f"File: {fp}, Prediction: {pred}, True Label: {label}\n")

    print(f"Validation results saved to {output_file_path}")

# %%
# #Run
# print("Training the model...")
# train(model, train_loader, criterion, optimizer, device, num_epochs=20)

# #load the saved model
# load_model(model, model_save_path)

# print("Evaluating the model on validation set...")
# val_loss, val_accuracy, val_preds, val_labels = evaluate(model, val_loader, criterion, device)

# print("Evaluating the model on test set...")
# test_loss, test_accuracy, test_preds, test_labels = evaluate(model, test_loader, criterion, device)

print("Running manual validation...")
manual_validation(test_loader.dataset.file_paths, test_labels, test_preds, base_dir)
# Out:
# Running manual validation...
# Validation results saved to /home/gridsan/abradshaw/MIT Buzz/manual_validation_results/validation_results_20240604_164150.txt
