# %%
import subprocess
import resampy
print(resampy.__version__)
# Define the path to the start_training.py script
training_script_path = '/home/gridsan/abradshaw/MITBuzz/ANIMAL-SPOT/TRAINING/start_training.py'
# Define the path to the config file
config_file_path = '/home/gridsan/abradshaw/MITBuzz/ANIMAL-SPOT/TRAINING/config'
# Run the training script with the config file path as an argument
result = subprocess.run(['python', training_script_path, config_file_path], capture_output=True, text=True)

# Print the output of the script
print(result.stdout)
print(result.stderr)
# Out:
# 0.4.3
#
# ...

# %%
import sys
print(sys.executable)
print(sys.path)
# Out:
# /home/gridsan/abradshaw/.conda/envs/python39++/bin/python
# ['/home/gridsan/abradshaw/.conda/envs/python39++/lib/python39.zip', '/home/gridsan/abradshaw/.conda/envs/python39++/lib/python3.9', '/home/gridsan/abradshaw/.conda/envs/python39++/lib/python3.9/lib-dynload', '', '/home/gridsan/abradshaw/.local/lib/python3.9/site-packages', '/home/gridsan/abradshaw/.conda/envs/python39++/lib/python3.9/site-packages']
